# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
from time_series_loader.load_file import FileDataFrame
from time_series_loader.file_metadata_parser import TimeMetadataExtractor

# %%
# Full path to all data folders (inside you have "folder1" folder, "another_folder" folder, etc)
PATH = '~/data/'

full_path = Path(PATH).expanduser()
full_path

# %% [markdown]
# ## Initialize the dataframe

# %%
files_1B = [
    'D2 - UPS Supply 1B - Data_Tot - 01-01-2024 00_00_00 - 10-14-2024 23_59_59.csv',
    'D2 - UPS Supply 1B - Data_Tot - 09-01-2022 00_00_00 - 12-31-2023 23_59_59.csv']
files_new = [
    '565Q4 - Data_All - 01-01-2022 00_00_00 - 12-31-2022 23_59_59.csv',
    '565Q4 - Data_All - 01-01-2023 00_00_00 - 12-31-2023 23_59_59.csv',
    '565Q4 - Data_All - 01-01-2024 00_00_00 - 12-31-2024 23_59_59.csv',
]
files_1A = [
   'D2 - UPS Supply 1A - DataTot - 09-01-2022 00_00_00 - 10-14-2024 23_59_59.csv',
]

# Here, files have dates of start and end in the names. I will use specialized extractor to work with them
files_1B = [full_path.joinpath('Main_LV_1B_Tot', file_1B) for file_1B in files_1B]
dataframe1B_D2 = FileDataFrame(files=files_1B, metadata_extractor=TimeMetadataExtractor())

# %% [markdown]
# ## Steps to charge
# ### Discovering all files
#
# We make certain assumptions regarding:
# * The fact that the files should be sorted in subfolder for each armoire. And the subfolder name should contain its identifier (e.g. '1A', '2C', etc)
# * The data should we in csv format
# * They could be in one file or in several files for one type of a charge
# * The format of the filename is 'armoire charge - Data - MM-DD-YYYY_HH_MM_SS - MM-DD-YYYY_HH_MM_SS.csv"
#
# Product: file list

# %%
files = dataframe1B_D2.discover_files()

# %%
dataframe1B_D2.get_discovery_stats()
# Out:
# {'total_files_found': 2,
#  'valid_files': 2,
#  'invalid_files': 0,
#  'invalid_files_details': []}

# %% [markdown]
# ### Process metadata
#
# We contruct metadata in this step that will be used to directly load and concatenate the files if necessary
#
# Procuct: self.metadata

# %%
dataframe1B_D2.process_files(files)
# Out:
# [FileMetadata(filepath=WindowsPath('C:/Users/dbryzgal/data/_clients/load_monitoring_se/full/Main_LV_1B_Tot/D2 - UPS Supply 1B - Data_Tot - 09-01-2022 00_00_00 - 12-31-2023 23_59_59.csv'), start_time=datetime.datetime(2022, 9, 1, 0, 0), end_time=datetime.datetime(2023, 12, 31, 23, 59, 59), additional_metadata={'has_timestamp_metadata': True}),
#  FileMetadata(filepath=WindowsPath('C:/Users/dbryzgal/data/_clients/load_monitoring_se/full/Main_LV_1B_Tot/D2 - UPS Supply 1B - Data_Tot - 01-01-2024 00_00_00 - 10-14-2024 23_59_59.csv'), start_time=datetime.datetime(2024, 1, 1, 0, 0), end_time=datetime.datetime(2024, 10, 14, 23, 59, 59), additional_metadata={'has_timestamp_metadata': True})]

# %%
dataframe1B_D2.get_processing_summary()
# Out:
# {'status': 'metadata_extracted',
#  'errors': {'total': 0,
#   'by_severity': {'CRITICAL': 0, 'ERROR': 0, 'WARNING': 0, 'INFO': 0}},
#  'files': {'discovered': 2, 'valid': 2, 'invalid': 0, 'processed': 2},
#  'data': {'loaded': False, 'rows': 0, 'columns': 0}}

# %% [markdown]
# ### Load files
#
# Load and concatenate (if needed csv files) into dataframes, validating that different files
# have the same structure and creating concatenated metadata that have the following fields:
# * number of lines
# * number of files
# * memory usage
# * start time
# * end time
#
# Products: self.dataframe and self.concat_metadata

# %%
dataframe1B_D2.load_and_concatenate()
dataframe1B_D2.dataframe

# %%
dataframe1B_D2.get_concat_metadata()
# Out:
# {'total_rows': 73205,
#  'total_files': 2,
#  'memory_usage': np.int64(73790768),
#  'start_time': datetime.datetime(2022, 9, 1, 0, 0),
#  'end_time': datetime.datetime(2023, 12, 31, 23, 59, 59)}

# %% [markdown]
# ### (Optinal) Check for time continuity problems in the data frames. Now it checks only for gaps
#
# It can find the datetime column, it can detect the frequency of the time series,
# and also there is a minimum gap allowed (1 min by default)
#
# Product: self.time_series_analysis

# %%
dataframe1B_D2.analyze_time_series_continuity(time_column='Date')
# Out:
# {'time_column': 'Date',
#  'min_gap_size': '1min',
#  'inferred_frequency': '900s',
#  'total_points': 73205,
#  'start_time': Timestamp('2022-09-07 17:00:00'),
#  'end_time': Timestamp('2024-10-14 23:59:00'),
#  'total_duration': Timedelta('768 days 06:59:00'),
#  'total_gaps': 158,
#  'total_gap_duration': Timedelta('7 days 10:00:00'),
#  'coverage_percentage': 99.03465393518623,
#  'gaps': [{'start_time': Timestamp('2022-09-08 01:45:00'),
#    'end_time': Timestamp('2022-09-08 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2022-09-08 15:45:00'),
#    'end_time': Timestamp('2022-09-08 16:30:00'),
#    'duration': Timedelta('0 days 00:45:00'),
#    'expected_points': 2},
#   {'start_time': Timestamp('2022-09-15 09:45:00'),
#    'end_time': Timestamp('2022-09-15 10:30:00'),
#    'duration': Timedelta('0 days 00:45:00'),
#    'expected_points': 2},
#   {'start_time': Timestamp('2022-09-17 12:00:00'),
#    'end_time': Timestamp('2022-09-17 13:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2022-09-21 18:00:00'),
#    'end_time': Timestamp('2022-09-21 18:45:00'),
#    'duration': Timedelta('0 days 00:45:00'),
#    'expected_points': 2},
#   {'start_time': Timestamp('2022-09-29 00:00:00'),
#    'end_time': Timestamp('2022-09-29 01:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2022-09-30 10:00:00'),
#    'end_time': Timestamp('2022-09-30 11:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2022-10-02 00:00:00'),
#    'end_time': Timestamp('2022-10-02 01:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2022-10-05 01:45:00'),
#    'end_time': Timestamp('2022-10-05 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2022-10-30 01:45:00'),
#    'end_time': Timestamp('2022-10-30 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2022-11-13 01:45:00'),
#    'end_time': Timestamp('2022-11-13 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2022-11-27 01:45:00'),
#    'end_time': Timestamp('2022-11-27 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2022-11-27 18:00:00'),
#    'end_time': Timestamp('2022-11-27 19:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2022-12-02 13:15:00'),
#    'end_time': Timestamp('2022-12-02 13:45:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2022-12-16 01:45:00'),
#    'end_time': Timestamp('2022-12-16 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2022-12-30 01:45:00'),
#    'end_time': Timestamp('2022-12-30 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-01-04 21:00:00'),
#    'end_time': Timestamp('2023-01-04 23:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-01-05 00:00:00'),
#    'end_time': Timestamp('2023-01-05 01:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-05 03:00:00'),
#    'end_time': Timestamp('2023-01-05 04:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-05 05:00:00'),
#    'end_time': Timestamp('2023-01-05 06:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-05 08:00:00'),
#    'end_time': Timestamp('2023-01-05 10:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-01-05 11:00:00'),
#    'end_time': Timestamp('2023-01-05 12:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-05 16:00:00'),
#    'end_time': Timestamp('2023-01-05 17:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-05 21:00:00'),
#    'end_time': Timestamp('2023-01-05 22:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-06 02:00:00'),
#    'end_time': Timestamp('2023-01-06 03:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-06 06:00:00'),
#    'end_time': Timestamp('2023-01-06 07:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-06 11:00:00'),
#    'end_time': Timestamp('2023-01-06 12:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-06 17:00:00'),
#    'end_time': Timestamp('2023-01-06 20:15:00'),
#    'duration': Timedelta('0 days 03:15:00'),
#    'expected_points': 12},
#   {'start_time': Timestamp('2023-01-06 21:00:00'),
#    'end_time': Timestamp('2023-01-06 22:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-06 23:00:00'),
#    'end_time': Timestamp('2023-01-07 02:15:00'),
#    'duration': Timedelta('0 days 03:15:00'),
#    'expected_points': 12},
#   {'start_time': Timestamp('2023-01-07 04:00:00'),
#    'end_time': Timestamp('2023-01-07 05:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-07 11:00:00'),
#    'end_time': Timestamp('2023-01-07 12:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-07 13:00:00'),
#    'end_time': Timestamp('2023-01-07 14:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-07 19:00:00'),
#    'end_time': Timestamp('2023-01-07 21:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-01-07 23:00:00'),
#    'end_time': Timestamp('2023-01-08 00:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-08 04:00:00'),
#    'end_time': Timestamp('2023-01-08 05:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-08 06:00:00'),
#    'end_time': Timestamp('2023-01-08 07:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-08 12:00:00'),
#    'end_time': Timestamp('2023-01-08 13:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-08 15:00:00'),
#    'end_time': Timestamp('2023-01-08 16:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-08 23:00:00'),
#    'end_time': Timestamp('2023-01-09 01:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-01-09 10:00:00'),
#    'end_time': Timestamp('2023-01-09 12:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-01-09 13:00:00'),
#    'end_time': Timestamp('2023-01-09 14:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-09 16:00:00'),
#    'end_time': Timestamp('2023-01-09 18:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-01-13 01:45:00'),
#    'end_time': Timestamp('2023-01-13 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-01-25 22:00:00'),
#    'end_time': Timestamp('2023-01-25 23:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-01-26 12:30:00'),
#    'end_time': Timestamp('2023-01-26 14:30:00'),
#    'duration': Timedelta('0 days 02:00:00'),
#    'expected_points': 7},
#   {'start_time': Timestamp('2023-01-31 08:00:00'),
#    'end_time': Timestamp('2023-01-31 09:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-02-04 07:00:00'),
#    'end_time': Timestamp('2023-02-04 08:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-02-14 01:45:00'),
#    'end_time': Timestamp('2023-02-14 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-02-25 03:00:00'),
#    'end_time': Timestamp('2023-02-25 04:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-02-28 01:45:00'),
#    'end_time': Timestamp('2023-02-28 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-03-01 02:00:00'),
#    'end_time': Timestamp('2023-03-01 03:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-01 05:00:00'),
#    'end_time': Timestamp('2023-03-01 06:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-01 09:00:00'),
#    'end_time': Timestamp('2023-03-01 10:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-01 14:00:00'),
#    'end_time': Timestamp('2023-03-01 16:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-03-01 18:00:00'),
#    'end_time': Timestamp('2023-03-01 19:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-03 06:00:00'),
#    'end_time': Timestamp('2023-03-03 07:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-03 11:00:00'),
#    'end_time': Timestamp('2023-03-03 12:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-03 20:00:00'),
#    'end_time': Timestamp('2023-03-03 21:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-04 00:00:00'),
#    'end_time': Timestamp('2023-03-04 01:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-04 15:00:00'),
#    'end_time': Timestamp('2023-03-04 16:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-04 21:00:00'),
#    'end_time': Timestamp('2023-03-04 22:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-05 08:00:00'),
#    'end_time': Timestamp('2023-03-05 09:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-05 16:00:00'),
#    'end_time': Timestamp('2023-03-05 17:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-06 12:00:00'),
#    'end_time': Timestamp('2023-03-06 13:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-06 21:00:00'),
#    'end_time': Timestamp('2023-03-06 22:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-06 23:00:00'),
#    'end_time': Timestamp('2023-03-07 00:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-07 03:00:00'),
#    'end_time': Timestamp('2023-03-07 04:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-07 09:00:00'),
#    'end_time': Timestamp('2023-03-07 10:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-07 13:00:00'),
#    'end_time': Timestamp('2023-03-07 15:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-03-07 17:00:00'),
#    'end_time': Timestamp('2023-03-07 18:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-07 20:00:00'),
#    'end_time': Timestamp('2023-03-07 21:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-09 05:00:00'),
#    'end_time': Timestamp('2023-03-09 06:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-09 10:00:00'),
#    'end_time': Timestamp('2023-03-09 11:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-10 05:00:00'),
#    'end_time': Timestamp('2023-03-10 08:15:00'),
#    'duration': Timedelta('0 days 03:15:00'),
#    'expected_points': 12},
#   {'start_time': Timestamp('2023-03-10 12:00:00'),
#    'end_time': Timestamp('2023-03-10 13:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-10 17:00:00'),
#    'end_time': Timestamp('2023-03-10 18:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-11 06:00:00'),
#    'end_time': Timestamp('2023-03-11 07:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-11 09:00:00'),
#    'end_time': Timestamp('2023-03-11 10:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-12 06:00:00'),
#    'end_time': Timestamp('2023-03-12 07:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-13 14:00:00'),
#    'end_time': Timestamp('2023-03-13 15:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-14 01:45:00'),
#    'end_time': Timestamp('2023-03-14 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-03-14 11:00:00'),
#    'end_time': Timestamp('2023-03-14 12:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-14 19:00:00'),
#    'end_time': Timestamp('2023-03-14 20:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-14 21:00:00'),
#    'end_time': Timestamp('2023-03-14 22:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-15 03:00:00'),
#    'end_time': Timestamp('2023-03-15 04:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-15 07:00:00'),
#    'end_time': Timestamp('2023-03-15 08:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-15 10:00:00'),
#    'end_time': Timestamp('2023-03-15 11:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-15 13:00:00'),
#    'end_time': Timestamp('2023-03-15 14:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-15 17:00:00'),
#    'end_time': Timestamp('2023-03-15 18:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-15 22:00:00'),
#    'end_time': Timestamp('2023-03-15 23:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-16 11:00:00'),
#    'end_time': Timestamp('2023-03-16 12:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-16 18:00:00'),
#    'end_time': Timestamp('2023-03-16 19:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-17 10:00:00'),
#    'end_time': Timestamp('2023-03-17 11:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-17 17:00:00'),
#    'end_time': Timestamp('2023-03-17 18:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-20 09:00:00'),
#    'end_time': Timestamp('2023-03-20 10:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-20 14:00:00'),
#    'end_time': Timestamp('2023-03-20 15:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-21 02:00:00'),
#    'end_time': Timestamp('2023-03-21 04:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-03-21 07:00:00'),
#    'end_time': Timestamp('2023-03-21 08:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-21 09:00:00'),
#    'end_time': Timestamp('2023-03-21 10:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-21 15:00:00'),
#    'end_time': Timestamp('2023-03-21 16:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-22 09:00:00'),
#    'end_time': Timestamp('2023-03-22 11:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2023-03-22 15:00:00'),
#    'end_time': Timestamp('2023-03-22 16:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-22 19:00:00'),
#    'end_time': Timestamp('2023-03-22 20:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-23 03:00:00'),
#    'end_time': Timestamp('2023-03-23 04:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-23 06:00:00'),
#    'end_time': Timestamp('2023-03-23 07:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-23 12:00:00'),
#    'end_time': Timestamp('2023-03-23 13:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-23 23:00:00'),
#    'end_time': Timestamp('2023-03-24 00:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-24 03:00:00'),
#    'end_time': Timestamp('2023-03-24 04:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-24 07:00:00'),
#    'end_time': Timestamp('2023-03-24 08:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-25 10:00:00'),
#    'end_time': Timestamp('2023-03-25 11:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-25 12:00:00'),
#    'end_time': Timestamp('2023-03-25 13:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-03-28 01:45:00'),
#    'end_time': Timestamp('2023-03-28 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-04-11 01:45:00'),
#    'end_time': Timestamp('2023-04-11 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-04-25 01:45:00'),
#    'end_time': Timestamp('2023-04-25 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-05-09 01:45:00'),
#    'end_time': Timestamp('2023-05-09 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-05-23 01:45:00'),
#    'end_time': Timestamp('2023-05-23 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-05-23 10:00:00'),
#    'end_time': Timestamp('2023-05-23 14:15:00'),
#    'duration': Timedelta('0 days 04:15:00'),
#    'expected_points': 16},
#   {'start_time': Timestamp('2023-06-06 01:45:00'),
#    'end_time': Timestamp('2023-06-06 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-06-20 01:45:00'),
#    'end_time': Timestamp('2023-06-20 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-07-04 01:45:00'),
#    'end_time': Timestamp('2023-07-04 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-07-18 01:45:00'),
#    'end_time': Timestamp('2023-07-18 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-08-01 01:45:00'),
#    'end_time': Timestamp('2023-08-01 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-08-17 01:45:00'),
#    'end_time': Timestamp('2023-08-17 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-08-31 01:45:00'),
#    'end_time': Timestamp('2023-08-31 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-09-14 01:45:00'),
#    'end_time': Timestamp('2023-09-14 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-09-28 01:45:00'),
#    'end_time': Timestamp('2023-09-28 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-10-11 14:00:00'),
#    'end_time': Timestamp('2023-10-11 15:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2023-10-12 01:45:00'),
#    'end_time': Timestamp('2023-10-12 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-10-26 01:45:00'),
#    'end_time': Timestamp('2023-10-26 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-11-09 01:45:00'),
#    'end_time': Timestamp('2023-11-09 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-11-23 01:45:00'),
#    'end_time': Timestamp('2023-11-23 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-12-07 01:45:00'),
#    'end_time': Timestamp('2023-12-07 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2023-12-21 01:45:00'),
#    'end_time': Timestamp('2023-12-21 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-01-04 01:45:00'),
#    'end_time': Timestamp('2024-01-04 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-01-22 01:45:00'),
#    'end_time': Timestamp('2024-01-22 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-02-05 01:45:00'),
#    'end_time': Timestamp('2024-02-05 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-02-19 01:45:00'),
#    'end_time': Timestamp('2024-02-19 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-03-04 01:45:00'),
#    'end_time': Timestamp('2024-03-04 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-03-18 01:45:00'),
#    'end_time': Timestamp('2024-03-18 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-04-01 01:45:00'),
#    'end_time': Timestamp('2024-04-01 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-04-15 01:45:00'),
#    'end_time': Timestamp('2024-04-15 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-04-28 15:00:00'),
#    'end_time': Timestamp('2024-04-28 17:15:00'),
#    'duration': Timedelta('0 days 02:15:00'),
#    'expected_points': 8},
#   {'start_time': Timestamp('2024-05-12 01:45:00'),
#    'end_time': Timestamp('2024-05-12 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-05-13 17:00:00'),
#    'end_time': Timestamp('2024-05-13 18:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2024-05-26 01:45:00'),
#    'end_time': Timestamp('2024-05-26 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-05-31 17:00:00'),
#    'end_time': Timestamp('2024-05-31 18:15:00'),
#    'duration': Timedelta('0 days 01:15:00'),
#    'expected_points': 4},
#   {'start_time': Timestamp('2024-06-09 01:45:00'),
#    'end_time': Timestamp('2024-06-09 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-06-20 15:00:00'),
#    'end_time': Timestamp('2024-06-20 16:30:00'),
#    'duration': Timedelta('0 days 01:30:00'),
#    'expected_points': 5},
#   {'start_time': Timestamp('2024-06-23 01:45:00'),
#    'end_time': Timestamp('2024-06-23 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-07-07 01:45:00'),
#    'end_time': Timestamp('2024-07-07 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-07-21 01:45:00'),
#    'end_time': Timestamp('2024-07-21 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-08-04 01:45:00'),
#    'end_time': Timestamp('2024-08-04 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-08-18 01:45:00'),
#    'end_time': Timestamp('2024-08-18 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-09-01 01:45:00'),
#    'end_time': Timestamp('2024-09-01 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-09-15 01:45:00'),
#    'end_time': Timestamp('2024-09-15 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-09-29 01:45:00'),
#    'end_time': Timestamp('2024-09-29 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1},
#   {'start_time': Timestamp('2024-10-13 01:45:00'),
#    'end_time': Timestamp('2024-10-13 02:15:00'),
#    'duration': Timedelta('0 days 00:30:00'),
#    'expected_points': 1}]}

# %% [markdown]
# ### (Optional) Resampling
#
# One can define frequency to resample to, but by default it takes detected frequency from time series report.
#
# There are also methods to fill resulting for the future, but they are not used yet, as we need to diffentiate between nans that have been there before and resampled nans
#
# Also, there is a way to exclude very large gaps
#
# Product: resampled dataframe

# %%
resampled = dataframe1B_D2.resample_time_series(time_column='Date', frequency='15min')
resampled

# %%
print(len(resampled))
print(len(dataframe1B_D2.dataframe))
# Out:
# 73756
# 73205

# %% [markdown]
# ### To save time one can use initialise_processing() method to do first three mandatory steps

# %%
files_1A = [full_path.joinpath('Main_LV_1A_Tot', file_1A) for file_1A in files_1A]
dataframe1A_D2 = FileDataFrame(files=files_1A)

# Another way to process files (combine all three steps in one)
dataframe1A_D2.initialize_processing()
dataframe1A_D2.get_concat_metadata()
# Out:
# {'total_rows': 39806,
#  'total_files': 1,
#  'memory_usage': np.int64(32680854),
#  'start_time': None,
#  'end_time': None}

# %% [markdown]
# ## Get file without time in the filename

# %%
# Folder, not files
second_full_path = Path('~/data/examples_raw/02_Alamo').expanduser()

# Use a possibility to give a folder
alamo_ts = FileDataFrame(base_path=second_full_path)

# %%
# Process files
files = alamo_ts.discover_files()
alamo_ts.get_discovery_stats()
# Out:
# {'total_files_found': 2,
#  'valid_files': 2,
#  'invalid_files': 0,
#  'invalid_files_details': [],
#  'glob_pattern': '*',
#  'recursive': False}

# %%
alamo_ts.process_files(files)
alamo_ts.get_processing_summary()
# Out:
# {'status': 'metadata_extracted',
#  'errors': {'total': 0,
#   'by_severity': {'CRITICAL': 0, 'ERROR': 0, 'WARNING': 0, 'INFO': 0}},
#  'files': {'discovered': 2, 'valid': 2, 'invalid': 0, 'processed': 2},
#  'data': {'loaded': False, 'rows': 0, 'columns': 0}}

# %%
alamo_ts.load_and_concatenate()
alamo_ts.get_concat_metadata()
# Out:
# {'total_rows': 518644,
#  'total_files': 2,
#  'memory_usage': np.int64(462758208),
#  'start_time': None,
#  'end_time': None}

# %%
alamo_ts.get_dataframe()
